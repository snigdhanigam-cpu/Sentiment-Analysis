# %%
import pandas as pd

df = pd.read_csv("high_similarity_articles_advanced_sentiment.csv")  
print(df.head())
# Out:
#    newspaper_index  nepal_index  similarity  \
# 0                0            0    0.447241
# 1               14            1    0.991284
# 2               14            3    0.421206
# 3               66            4    1.000000
# 4              109            7    0.421495
#
#                                      newspaper_title  \
# 0  The Inside Story of How Gen Z Toppled Nepal’s ...
# 1  ‘More egalitarian’: How Nepal’s Gen Z used gam...
# 2  ‘More egalitarian’: How Nepal’s Gen Z used gam...
# 3  Nepal’s Social Media Elects Their Prime Minist...
# 4  Who is Sushila Karki, Nepal’s new 73-year-old ...
#
#                                          nepal_title  \
# 0  The Inside Story of How Gen Z Toppled Nepal’s ...
# 1  ‘More egalitarian’: How Nepal’s Gen Z used gam...
# 2                                                NaN
# 3                                     The New Dealer
# 4  Former chief justice sworn in as Nepal’s inter...
#
# ...

# %%
print(df)

print(df.info())

print(df.describe())
# Out:
#     newspaper_index  nepal_index  similarity  \
# 0                 0            0    0.447241
# 1                14            1    0.991284
# 2                14            3    0.421206
# 3                66            4    1.000000
# 4               109            7    0.421495
# 5               123            8    0.971101
# 6               145            9    0.940892
# 7               151            9    0.402812
# 8               194            3    0.425491
# 9               194           22    0.845758
# 10              198           13    0.974425
# 11              203            2    0.909204
# 12              233           16    0.897979
#
#                                       newspaper_title  \
# 0   The Inside Story of How Gen Z Toppled Nepal’s ...
# 1   ‘More egalitarian’: How Nepal’s Gen Z used gam...
# 2   ‘More egalitarian’: How Nepal’s Gen Z used gam...
# 3   Nepal’s Social Media Elects Their Prime Minist...
# ...
